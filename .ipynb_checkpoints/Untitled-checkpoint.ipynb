# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('dynamic_photofeeler.db')

# Exécuter une requête SQL
query = "SELECT * FROM Photos"
df_photos = pd.read_sql_query(query, conn)
print("Photos:")
print(df_photos)

query = "SELECT * FROM Scores"
df_scores = pd.read_sql_query(query, conn)
print("\nScores:")
print(df_scores)

query = "SELECT * FROM Votes"
df_votes = pd.read_sql_query(query, conn)
print("\nVotes:")
print(df_votes)

# Fermer la connexion
conn.close()
# Out:
# Photos:
#                                              photo_id categorie votes  \
# 0   https://www.photofeeler.com/my-tests#view/tsnu...    DATING    10
# 1   https://www.photofeeler.com/my-tests#view/tbc4...    DATING    11
# 2   https://www.photofeeler.com/my-tests#view/tddr...    DATING    15
# 3   https://www.photofeeler.com/my-tests#view/tpkh...    DATING    23
# 4   https://www.photofeeler.com/my-tests#view/td2n...    DATING     7
# 5   https://www.photofeeler.com/my-tests#view/tat4...    DATING     6
# 6   https://www.photofeeler.com/my-tests#view/tdgd...    DATING    10
# 7   https://www.photofeeler.com/my-tests#view/tsmj...    DATING    19
# 8   https://www.photofeeler.com/my-tests#view/t2oo...    DATING    10
# 9   https://www.photofeeler.com/my-tests#view/t8n3...    DATING    21
# 10  https://www.photofeeler.com/my-tests#view/ttf0...    DATING    12
# 11  https://www.photofeeler.com/my-tests#view/tvwu...    DATING    39
# ...

# %%
context = "SUBJECT - 27 / MALE\n VOTERS - ALL"
context.strip(" ")
# Out:
# 'SUBJECT - 27 / MALE\n VOTERS - ALL'
